# %%
data = [{'title': '&“~ EUROCORPORATION PER UFFICIO'},
 {'key': 'COMUNE DI PISTOIA PRODUTTORE COMUNE DI PISTOIA CLIENTE'},
 {'value': 'Via Dino Buzzati, 1 51100 PISTOIA (PT)'},
 {'key': 'Operatore'},
 {'value': 'Francesca Buffolino - Mob. 327 6613420'},
 {'key': 'Unit. Loc. Referente'},
 {'value': 'Francesco Andreotti'},
 {'key': 'CF Produttore'},
 {'value': '00108690470'},
 {'key': 'Telefono Email Cliente'},
 {'value': '366/3488969 f.andreotti@comune.pistoia.it'},
 {'key': 'Data Richiesta'},
 {'value': '25/02/2022'},
 {'key': 'Orario richiesta Email Produttore'},
 {'value': 'f.andreotti@comune.pistoia.it'},
 {'key': 'Mattina Dalle'},
 {'value': '08:00'},
 {'title': 'PER LA LOGISTICA:'},
 {'value': 'Alle 17:00 SCHEDA FATTA DA MATILDE'},
 {'key': 'Pomeriggio Dalle'},
 {'value': '14:30 CHIAMARE ALMENO DUE GIORNI PRIMA PER CONFERMA DATA E VEICOLO RICHIESTO ORARIO DAL LUNEDi AL VENERDi 08:00 13:00 MARTEDi E GIOVED 14:30 17:00 CAMBIO CASSONE DA 30MC https://www.google.com/maps/@43.9305451,10.9433864,3a,75y ,179.63h,86.79t/data=!3m6!1e1!3m4! 1sqBwGa7tckBjoehYHEWaJdg!2e0!7i116384!8i8192'},
 {'key': 'Tipologia rifiuto'},
 {'title': 'ADR CER DESCRIZIONE'},
 {'key': 'Classe Pericolo: Destino:'},
 {'value': 'R13 170201 Solido non pulverulento'},
 {'key': 'Confezionamento:'},
 {'value': 'SFUSO EUROCORPORATION'},
 {'key': 'Destinazione:'},
 {'value': 'EUROCORPORATION S.r.I. C.F. - P.iva 05235640488 R.E.A. 531452 Capitale Sociale € 100.000,000 Via de’ Cattani 178 - 50145 Firenze | Tel. 055 7222419 Fax 055 7227520 info@eurocorporation.it | info@pec.eurocorporation.it | www.eurocorporation.it'}]

# %%
import pandas as pd
len_data = len(data)
key_list =[]
value_list = []
for i in data:
    for k, v in i.items():
        if k == 'key':
            key_list.append(v)
        if k == 'value':
            value_list.append(v)
print(len(key_list), key_list)
print(len(value_list), value_list)

df = pd.DataFrame({'key': key_list, 'value':value_list})
# Out:
# 13 ['COMUNE DI PISTOIA PRODUTTORE COMUNE DI PISTOIA CLIENTE', 'Operatore', 'Unit. Loc. Referente', 'CF Produttore', 'Telefono Email Cliente', 'Data Richiesta', 'Orario richiesta Email Produttore', 'Mattina Dalle', 'Pomeriggio Dalle', 'Tipologia rifiuto', 'Classe Pericolo: Destino:', 'Confezionamento:', 'Destinazione:']
# ...

# %%
df
# Out:
#                                                   key  \
# 0   COMUNE DI PISTOIA PRODUTTORE COMUNE DI PISTOIA...
# 1                                           Operatore
# 2                                Unit. Loc. Referente
# 3                                       CF Produttore
# 4                              Telefono Email Cliente
# 5                                      Data Richiesta
# 6                   Orario richiesta Email Produttore
# 7                                       Mattina Dalle
# 8                                    Pomeriggio Dalle
# 9                                   Tipologia rifiuto
# 10                          Classe Pericolo: Destino:
# 11                                   Confezionamento:
# 12                                      Destinazione:
#
#                                                 value
# 0              Via Dino Buzzati, 1 51100 PISTOIA (PT)
# 1              Francesca Buffolino - Mob. 327 6613420
# ...

# %%
df.to_csv('resultFinal.csv')
